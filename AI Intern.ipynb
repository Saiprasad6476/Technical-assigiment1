# %%
###Problem 1 – Time Slot Consolidation Problem Statement
data = list(map(int, input().split()))

n = data[0]
intervals = []

idx = 1
for i in range(n):
    intervals.append([data[idx], data[idx + 1]])
    idx += 2

intervals.sort()

merged = []

for interval in intervals:
    if not merged or interval[0] > merged[-1][1]:
        merged.append(interval)
    else:
        merged[-1][1] = max(merged[-1][1], interval[1])

for start, end in merged:
    print(start, end)
# Out:
#  3  1 10  2 8  3 7
# 1 10

# %%
###Problem 2 – Maximum Signal Strength Problem Statement
data = list(map(int, input().split()))

n = data[0]

arr = data[1:n + 1]

k = data[n + 1]

window_sum = sum(arr[:k])
max_sum = window_sum

for i in range(k, n):
    window_sum += arr[i] - arr[i - k]6

4 -1 2 1 -5 4

2
    max_sum = max(max_sum, window_sum)

print(max_sum)
# Out:
#  6  2 1 5 1 3 2  3
# 9

# %%
data = list(map(int, input().split()))

n = data[0]
arr = data[1:n + 1]
k = data[n + 1]

window_sum = sum(arr[:k])
max_sum = window_sum

for i in range(k, n):
    window_sum += arr[i] - arr[i - k]
    max_sum = max(max_sum, window_sum)

print(max_sum)
# Out:
#  4  1 2 3 4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 5
#       3 n = data[0]
#       4 arr = data[1:n + 1]
# ----> 5 k = data[n + 1]
#       7 window_sum = sum(arr[:k])
#       8 max_sum = window_sum
#
# IndexError: list index out of range

# %%
data = list(map(int, input().split()))

n = data[0]
arr = data[1:n + 1]
k = data[n + 1]

window_sum = sum(arr[:k])
max_sum = window_sum

for i in range(k, n):
    window_sum += arr[i] - arr[i - k]
    max_sum = max(max_sum, window_sum)

print(max_sum)
# Out:
#  5  -8 -3 -6 -2 -5  2
# -7

# %%
data = list(map(int, input().split()))

n = data[0]

arr = data[1:n + 1]

k = data[n + 1]

window_sum = sum(arr[:k])
max_sum = window_sum

for i in range(k, n):
    window_sum += arr[i] - arr[i - k]
    max_sum = max(max_sum, window_sum)

print(max_sum)
# Out:
#  5  4 2 7 1 9  1
# 9

# %%
data = list(map(int, input().split()))

n = data[0]
arr = data[1:n + 1]
k = data[n + 1]

window_sum = sum(arr[:k])
max_sum = window_sum

for i in range(k, n):
    window_sum += arr[i] - arr[i - k]
    max_sum = max(max_sum, window_sum)

print(max_sum)
# Out:
#  5  1 2 3 4 5  3
# 12

# %%
data = list(map(int, input().split()))

n = data[0]
arr = data[1:n + 1]
k = data[n + 1]

window_sum = sum(arr[:k])
max_sum = window_sum

for i in range(k, n):
    window_sum += arr[i] - arr[i - k]
    max_sum = max(max_sum, window_sum)

print(max_sum)
# Out:
#  6  4 -1 2 1 -5 4  2
# 3

# %%
##3Problem 3 – Communication Channel Analyzer Problem Statement
s = input().strip()

seen = {}
left = 0
max_len = 0

for right in range(len(s)):
    if s[right] in seen and seen[s[right]] >= left:
        left = seen[s[right]] + 1

    seen[s[right]] = right
    max_len = max(max_len, right - left + 1)

print(max_len)
